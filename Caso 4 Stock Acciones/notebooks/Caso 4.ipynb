# %% [markdown]
# <!-- EXPORT: TITULO -->
# <div style="
# background:#1e1e1e;
# padding:35px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h1 style="
# font-size:55px;
# color:#60a5fa;
# text-align:center;
# margin-top:0;
# margin-bottom:10px;
# ">
# Caso de Negocio 4
# </h1>
#
# <h2 style="
# font-size:35px;
# color:#f3f4f6;
# text-align:center;
# font-weight:normal;
# margin-top:0;
# margin-bottom:25px;
# ">
# Análisis Exploratorio del Rendimiento de las Empresas con Mayor Capitalización Bursátil (2018–2023)
# </h2>
#
# <hr style="border:5px solid #374151;margin-bottom:30px;">
# <hr style="border:3px solid #374151;margin-bottom:30px;">
# <hr style="border:1px solid #374151;margin-bottom:30px;">
#
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:35px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h3 style="
# font-size:35px;
# color:#60a5fa;
# margin-bottom:10px;
# ">
# Contexto del negocio
# </h3>
#
# </div>

# %% [markdown]
# <!-- EXPORT: CONTEXTO -->
# <div style="
# background:#1e1e1e;
# padding:35px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:17px;
# color:#d1d5db;
# line-height:1.8;
# text-align:justify;
# ">
# Una firma de inversión desea comprender el comportamiento histórico de las principales empresas que cotizan en el mercado bursátil estadounidense con el objetivo de identificar patrones de crecimiento, volatilidad y actividad de negociación que sirvan como apoyo para futuros análisis financieros y la toma de decisiones de inversión.
# </p>
#
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:35px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h3 style="
# font-size:35px;
# color:#60a5fa;
# margin-bottom:10px;
# ">
# Objetivo general
# </h3>
#
# </div>

# %% [markdown]
# <!-- EXPORT: OBJETIVO -->
# <div style="
# background:#1e1e1e;
# padding:35px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:17px;
# color:#d1d5db;
# line-height:1.8;
# text-align:justify;
# ">
# Analizar el comportamiento histórico del precio de las acciones, el volumen de negociación y el rendimiento acumulado de las principales empresas del mercado estadounidense durante el período 2018–2025 mediante técnicas de análisis exploratorio de datos, con el fin de identificar tendencias, niveles de volatilidad y diferencias entre compañías.
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h2 style="
# font-size:35px;
# color:#60a5fa;
# text-align:center;
# margin-top:0;
# margin-bottom:30px;
# ">
# Preguntas de negocio
# </h2>
#
# <ol style="
# font-size:17px;
# color:#d1d5db;
# line-height:2;
# padding-left:25px;
# ">
#
# <li><b>¿Cuáles empresas obtuvieron el mayor rendimiento acumulado?</b></li>
#
# <li><b>¿Cómo evolucionó el precio de cierre de las empresas con mayor rendimiento acumulado?</b></li>
#
# <li><b>¿Cómo se distribuyen los rendimientos diarios de las empresas con mayor rendimiento acumulado?</b></li>
#
# <li><b>¿Qué empresas registran los mayores volúmenes de negociación?</b></li>
#
# <li><b>¿Cómo se relacionan el volumen negociado y el precio de cierre?</b></li>
#
# <li><b>¿Cuál fue el rendimiento mensual promedio de cada empresa?</b></li>
#
# <li><b>¿Qué tan consistentes fueron los rendimientos diarios de las empresas con mayor rendimiento acumulado?</b></li>
#
# </ol>
#
# </div>

# %%
# Librerias
import sys
sys.path.append("..")

import numpy as np
import pandas as pd

from math import pi
from scipy.stats import gaussian_kde
from bokeh.layouts import column
from bokeh.models import (
    ColumnDataSource,
    CustomJS,
    DatetimeTickFormatter,
    GlobalInlineStyleSheet,
    HoverTool,
    Label,
    Legend,
    LegendItem,
    NumeralTickFormatter,
    RangeTool,
    TapTool,
    LabelSet, 
    Span,
    Select,
    InlineStyleSheet, 
    ColorBar
)
from bokeh.plotting import figure, show, output_notebook
from bokeh.transform import dodge, factor_cmap, linear_cmap
from bokeh.palettes import Inferno256, RdYlGn11

from utils import export_tables
from utils import export_charts
from utils import export_text
from utils import report

# %%
# Tema

output_notebook()

THEMES = {
    "market_dark": {

        "BACKGROUND": "#0a0a0a",
        "PANEL": "#171717",
        "GRID": "#374151",
        "GRID_ALPHA": 0.35,
        "BORDER": "#4b5563",
        "TEXT": "#f8fafc",
        "TEXT_SOFT": "#cbd5e1",
        "TEXT_SIZE": "10pt",
        "ACCENT": "#3b82f6",
        "POSITIVE": "#22c55e",
        "NEGATIVE": "#ef4444",
        "WARNING": "#f59e0b",
        "COLORS": {

            "PRIMARY": "#3b82f6",     # Azul
            "SECONDARY": "#8b5cf6",   # Morado
            "SUCCESS": "#22c55e",     # Verde
            "DANGER": "#ef4444",      # Rojo
            "WARNING": "#f59e0b",     # Amarillo
            "INFO": "#06b6d4",        # Cian
            "PINK": "#ec4899",
            "ORANGE": "#fb923c",
            "GRAY": "#94a3b8"

        }
    }
}

theme = THEMES["market_dark"]
colors = theme["COLORS"]

# %%
# Tables and Charts

TABLES = {}
CHARTS = {}

# %%
# Data Base

df = pd.read_csv(
    "../data/caso_4_lim.csv",
    parse_dates=["fecha"],
    dtype={
        "Company": "string",
        "Open": "float64",
        "High": "float64",
        "Low": "float64",
        "Close": "float64",
        "Volume": "int64",
        "Dividends": "float64",
        "Stock_Splits": "float64"
    }
)

df.drop(columns="Date", inplace=True)
df = df[["fecha", "Company", "Open", "High", "Low", "Close", "Volume", "Dividends", "Stock_Splits"]]
df.columns.name = None
TABLES["table"] = df
df

# %% [markdown]
# <!-- EXPORT: PREGUNTA_1 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Cuáles empresas obtuvieron el mayor rendimiento acumulado?</b>
# </ol>
#
# </div>

# %%
# Data Question 1

df_ques1 = (df.sort_values("fecha").groupby("Company").agg(Precio_Inicial=("Close","first"), Precio_Final=("Close","last")))
df_ques1["Rendimiento"] = (df_ques1["Precio_Final"]/df_ques1["Precio_Inicial"] - 1) * 100
df_ques1 = (df_ques1.sort_values("Rendimiento", ascending=False).head(10).reset_index())
df_ques1["Rendimiento_txt"] = (df_ques1["Rendimiento"].round(2).astype(str)+"%")
source = ColumnDataSource(df_ques1)

df_ques1.columns.name = None
TABLES["table_ques1"] = df_ques1
df_ques1

# %%
# Chart Question 1

p_ques1 = figure(
    y_range=list(df_ques1["Company"])[::-1],
    x_range=(0, 1350), 
    height=550,
    width=950,
    title="Top 10 Rendimiento de Empresas (2018-2023)",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    tools="pan,wheel_zoom,reset,save"
)

renderer = p_ques1.hbar(
    y="Company",
    right="Rendimiento",
    height=0.75,
    source=source,
    color=theme["ACCENT"]
)

labels = LabelSet(
    x="Rendimiento",       
    y="Company",         
    text="Rendimiento_txt", 
    level="glyph",
    x_offset=10,           
    y_offset=0,             
    source=source,
    text_font_size="10pt",
    text_color=theme["TEXT"]
)

hover = HoverTool(
    tooltips="""
    <div style="
        background:#111827;
        border:1px solid #3b82f6;
        border-radius:8px;
        padding:10px;
        color:#f8fafc;
        font-size:13px;
        line-height:1.5;
    ">
        <div><b>Company:</b> @Company</div>
        <div><b>Rendimiento:</b> <span style="color:#22c55e;">@Rendimiento{0.0}%</span></div>
    </div>
    """,
    renderers=[renderer]
)
p_ques1.stylesheets = [
    GlobalInlineStyleSheet(css="""
    .bk-Tooltip {
        --tooltip-color: transparent !important;
        --tooltip-border: transparent !important;
    }
    .bk-tooltip-content {
        background: transparent !important;
        border: none !important;
        box-shadow: none !important;
        padding: 0 !important;
    }
    """)
]
p_ques1.add_layout(labels)
p_ques1.add_tools(hover)
p_ques1.xaxis.major_label_orientation = 1.0  
p_ques1.title.text_color = theme["ACCENT"]
p_ques1.title.text_font_size = "20pt"
p_ques1.title.align = "center"
p_ques1.background_fill_color = theme["PANEL"]
p_ques1.border_fill_color = theme["BACKGROUND"]
p_ques1.outline_line_color = theme["BORDER"]
p_ques1.xaxis.axis_label_text_color = theme["TEXT"]
p_ques1.yaxis.axis_label_text_color = theme["TEXT"]
p_ques1.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques1.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques1.xaxis.axis_line_color = theme["TEXT_SOFT"]
p_ques1.yaxis.axis_line_color = theme["TEXT_SOFT"]
p_ques1.xaxis.major_tick_line_color = theme["TEXT_SOFT"]
p_ques1.yaxis.major_tick_line_color = theme["TEXT_SOFT"]
p_ques1.xaxis.minor_tick_line_color = theme["TEXT_SOFT"]
p_ques1.yaxis.minor_tick_line_color = theme["TEXT_SOFT"]
p_ques1.xgrid.grid_line_color = theme["GRID"]
p_ques1.ygrid.grid_line_color = theme["GRID"]
p_ques1.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques1.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques1.toolbar.logo = None
p_ques1.toolbar.autohide = True

CHARTS["chart_ques1"] = p_ques1
show(p_ques1)

# %% [markdown]
# <!-- EXPORT: ANALISIS_1 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Durante el período 2018–2025 se observa que el rendimiento acumulado de las empresas presenta una distribución heterogénea. NVIDIA registró el mayor crecimiento, alcanzando un rendimiento acumulado de <b>1131.46%</b>, seguida por Tesla con <b>990.14%</b> y BioNTech (BNTX) con <b>617.53%</b>. Estos resultados reflejan una apreciación significativa en el precio de sus acciones durante el período analizado, posicionándolas como las empresas con mayor retorno para un inversionista que hubiera mantenido su inversión desde el inicio hasta el final del horizonte de estudio.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Las empresas ubicadas entre la cuarta y la décima posición también presentan rendimientos acumulados positivos; sin embargo, muestran un comportamiento más homogéneo, con valores comprendidos entre <b>527.31%</b> y <b>478.65%</b>. Esta diferencia respecto a las tres primeras posiciones evidencia que el crecimiento del mercado no fue uniforme y que únicamente un grupo reducido de compañías logró obtener retornos excepcionalmente superiores al promedio.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Desde una perspectiva financiera, los resultados sugieren que las empresas del sector tecnológico dominaron el rendimiento bursátil durante el período analizado, consolidándose como uno de los segmentos con mayor generación de valor para los inversionistas. No obstante, el rendimiento histórico constituye únicamente una referencia y no garantiza resultados futuros, por lo que cualquier decisión de inversión debería complementarse con análisis fundamentales, evaluación del riesgo, condiciones del mercado y estudios estadísticos que permitan valorar la sostenibilidad del crecimiento observado.
# </p>
#
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_2 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Cómo evolucionó el precio de cierre de las empresas con mayor rendimiento acumulado?</b>
# </ol>
#
# </div>

# %%
# Data Question 2

df_ques2 = (df.loc[df["Company"].isin(df_ques1["Company"]),["Company", "fecha", "Close"]].copy())
df_ques2 = df_ques2.sort_values(["Company", "fecha"])
df_ques2["Indice"] = (df_ques2.groupby("Company")["Close"].transform(lambda x: x / x.iloc[0] * 100))
source = ColumnDataSource(df_ques2)
df_ques2.columns.name = None
TABLES["table_ques2"] = df_ques2
df_ques2

# %%
# Chart Question 2

p_ques2 = figure(
    width=950,
    height=550,
    x_axis_type="datetime",
    title="Evolución del rendimiento acumulado (Índice Base 100)",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    tools="pan,wheel_zoom,box_zoom,reset,save"
)

for empresa, datos in df_ques2.groupby("Company"):
    src = ColumnDataSource(datos)
    renderer = p_ques2.line(
        x="fecha",
        y="Indice",
        source=src,
        legend_label=empresa,
        line_width=2
    )

hover = HoverTool(
    tooltips="""
    <div style="
        background:#111827;
        border:1px solid #3b82f6;
        border-radius:8px;
        padding:10px;
        color:#f8fafc;
        font-size:13px;
        line-height:1.6;
    ">
        <div style="color:#60a5fa;font-weight:bold;font-size:14px;">@Company</div>
        <hr style="border:0;border-top:1px solid #374151;margin:6px 0;">
        <div><b>Fecha:</b> @fecha{%F}</div>
        <div><b>Índice:</b> @Indice{0.0}</div>
        <div><b>Precio:</b> $@Close{0.00}</div>
    </div>
    """,
    formatters={
        "@fecha": "datetime"
    }
)

p_ques2.add_tools(hover)
p_ques2.legend.location = "top_left"
p_ques2.legend.click_policy = "hide"
p_ques2.legend.background_fill_color = theme["PANEL"]
p_ques2.legend.background_fill_alpha = 0.90
p_ques2.legend.border_line_color = theme["BORDER"]
p_ques2.legend.label_text_color = theme["TEXT"]
p_ques2.yaxis.formatter = NumeralTickFormatter(format="0")
p_ques2.yaxis.axis_label = "Índice (Base 100)"
p_ques2.title.text_color = theme["ACCENT"]
p_ques2.title.text_font_size = "20pt"
p_ques2.title.align = "center"
p_ques2.background_fill_color = theme["PANEL"]
p_ques2.border_fill_color = theme["BACKGROUND"]
p_ques2.outline_line_color = theme["BORDER"]
p_ques2.xgrid.grid_line_color = theme["GRID"]
p_ques2.ygrid.grid_line_color = theme["GRID"]
p_ques2.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques2.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques2.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques2.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques2.xaxis.axis_label_text_color = theme["TEXT"]
p_ques2.yaxis.axis_label_text_color = theme["TEXT"]
p_ques2.toolbar.logo = None
p_ques2.toolbar.autohide = True

df_select = df_ques2[df_ques2["Company"] == "NVDA"]
source_select = ColumnDataSource(df_select)
select = figure(
    title="Seleccionar período",
    height=120,
    width=950,
    x_axis_type="datetime",
    y_axis_type=None,
    tools="",
    toolbar_location=None,
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"]
)

select.line(
    "fecha",
    "Indice",
    source=source_select,
    color=theme["ACCENT"],
    line_width=2
)

range_tool = RangeTool(x_range=p_ques2.x_range)
range_tool.overlay.fill_color = theme["ACCENT"]
range_tool.overlay.fill_alpha = 0.20
range_tool.overlay.line_color = theme["ACCENT"]
range_tool.overlay.line_width = 2
select.add_tools(range_tool)
select.background_fill_color = theme["PANEL"]
select.border_fill_color = theme["BACKGROUND"]
select.xgrid.grid_line_color = theme["GRID"]
select.ygrid.grid_line_color = theme["GRID"]
select.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
select.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
select.outline_line_color = theme["BORDER"]
select.yaxis.visible = False
select.title.text_color = theme["ACCENT"]
select.title.text_font_size = "12pt"

CHARTS["chart_ques2"] = column(p_ques2)
show(column(p_ques2, select))

# %% [markdown]
# <!-- EXPORT: ANALISIS_2 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Al analizar la evolución del precio de cierre utilizando un índice base 100 se observa que las empresas con mayor rendimiento acumulado siguieron trayectorias muy diferentes. BNTX presentó el comportamiento más volátil del grupo, alcanzando un máximo cercano a 3,140 puntos durante agosto de 2021 para posteriormente experimentar una fuerte corrección que redujo su índice hasta aproximadamente 718 puntos al finalizar el período analizado. Este comportamiento refleja un crecimiento acelerado seguido de una importante pérdida de valor relativo respecto a su máximo histórico.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Por su parte, TSLA también registró una elevada volatilidad. Su índice alcanzó un máximo cercano a 1,803 puntos durante noviembre de 2021; sin embargo, posteriormente presentó una corrección importante que redujo su desempeño hasta finalizar el período alrededor de 1,090 puntos. A pesar de esta disminución, la empresa mantuvo uno de los mayores rendimientos acumulados del conjunto analizado, evidenciando una apreciación considerable del precio de sus acciones durante el horizonte de estudio.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# En contraste, NVIDIA mostró una trayectoria de crecimiento más estable y sostenida. Aunque registró fluctuaciones propias del mercado, su comportamiento fue menos pronunciado que el observado en BNTX y TSLA. Además, finalizó el período con un índice cercano a 1,232 puntos y un máximo de aproximadamente 1,291 puntos, lo que sugiere una apreciación más consistente del precio de la acción y una menor dependencia de movimientos especulativos de corto plazo.
# </p>
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_3 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Cómo se distribuyen los rendimientos diarios de las empresas con mayor rendimiento acumulado?</b>
# </ol>
#
# </div>

# %%
# Data Question 3

df_ques3 = df[df["Company"].isin(df_ques1["Company"])][["fecha", "Company", "Close"]].copy()
df_ques3 = df_ques3.sort_values(["Company", "fecha"])
df_ques3["Retorno_Diario"] = (df_ques3.groupby("Company")["Close"].pct_change() * 100)
df_ques3 = (df_ques3[["fecha", "Company", "Retorno_Diario"]].dropna().reset_index(drop=True))
source = ColumnDataSource(df_ques3)
df_ques3.columns.name = None
TABLES["table_ques3"] = df_ques3
df_ques3

# %%
# Gráfica pregunta 3

groups = df_ques3.groupby("Company")
q1 = groups["Retorno_Diario"].quantile(0.25)
q2 = groups["Retorno_Diario"].quantile(0.50)
q3 = groups["Retorno_Diario"].quantile(0.75)
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr
upper_whisker = groups["Retorno_Diario"].max()
lower_whisker = groups["Retorno_Diario"].min()
upper_whisker = upper_whisker.combine(upper, min)
lower_whisker = lower_whisker.combine(lower, max)
outliers = df_ques3[(df_ques3["Retorno_Diario"] > df_ques3["Company"].map(upper)) | (df_ques3["Retorno_Diario"] < df_ques3["Company"].map(lower))]

box = pd.DataFrame({
    "Company": q1.index,
    "q1": q1.values,
    "q2": q2.values,
    "q3": q3.values,
    "upper": upper_whisker.values,
    "lower": lower_whisker.values
})
source = ColumnDataSource(box)

orden = (df_ques3.groupby("Company")["Retorno_Diario"].std().sort_values(ascending=False).index.tolist())

p_ques3 = figure(
    width=950,
    height=550,
    x_range=orden,
    title="Distribución de los rendimientos diarios",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    tools="pan,reset,save"
)

renderer_box = p_ques3.vbar(
    x="Company",
    width=0.6,
    bottom="q1",
    top="q3",
    source=source,
    fill_color=colors["PRIMARY"],
    line_color="white",
    alpha=0.8
)

p_ques3.segment(
    x0="Company",
    x1="Company",
    y0="upper",
    y1="q3",
    source=source,
    line_color="white"
)

p_ques3.segment(
    x0="Company",
    x1="Company",
    y0="lower",
    y1="q1",
    source=source,
    line_color="white"
)

p_ques3.segment(
    x0=dodge("Company", -0.30, range=p_ques3.x_range),
    y0="q2",
    x1=dodge("Company",  0.30, range=p_ques3.x_range),
    y1="q2",
    source=source,
    line_color="white",
    line_width=3
)

p_ques3.segment(
    x0=dodge("Company", -0.15, range=p_ques3.x_range),
    y0="upper",
    x1=dodge("Company",  0.15, range=p_ques3.x_range),
    y1="upper",
    source=source,
    line_color="white",
    line_width=2
)

p_ques3.segment(
    x0=dodge("Company", -0.15, range=p_ques3.x_range),
    y0="lower",
    x1=dodge("Company",  0.15, range=p_ques3.x_range),
    y1="lower",
    source=source,
    line_color="white",
    line_width=2
)

p_ques3.scatter(
    x="Company",
    y="Retorno_Diario",
    source=ColumnDataSource(outliers),
    size=4,
    color=colors["DANGER"],
    alpha=0.6
)

hover = HoverTool(
    renderers=[renderer_box],
    tooltips="""
    <div style="
        background:#111827;
        border:1px solid #3b82f6;
        border-radius:8px;
        padding:10px;
        color:#f8fafc;
    ">
        <b>Empresa:</b> @Company<br>
        <b>Q1:</b> @q1{0.00}%<br>
        <b>Mediana:</b> @q2{0.00}%<br>
        <b>Q3:</b> @q3{0.00}%<br>
    </div>
    """
)

p_ques3.add_tools(hover)
p_ques3.yaxis.axis_label = "Rendimiento diario (%)"
p_ques3.yaxis.formatter = NumeralTickFormatter(format="0.00")
p_ques3.title.text_color = theme["ACCENT"]
p_ques3.title.text_font_size = "20pt"
p_ques3.title.align = "center"
p_ques3.background_fill_color = theme["PANEL"]
p_ques3.border_fill_color = theme["BACKGROUND"]
p_ques3.outline_line_color = theme["BORDER"]
p_ques3.xgrid.grid_line_color = theme["GRID"]
p_ques3.ygrid.grid_line_color = theme["GRID"]
p_ques3.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques3.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques3.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques3.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques3.xaxis.axis_label_text_color = theme["TEXT"]
p_ques3.yaxis.axis_label_text_color = theme["TEXT"]
p_ques3.toolbar.logo = None
p_ques3.toolbar.autohide = True

CHARTS["chart_ques3"] = p_ques3
show(p_ques3)

# %% [markdown]
# <!-- EXPORT: ANALISIS_3 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# La distribución de los rendimientos diarios evidencia diferencias importantes en el nivel de riesgo entre las empresas con mayor rendimiento acumulado. BNTX presenta la mayor dispersión de rendimientos, con un rango intercuartílico aproximado entre -2.27% y 2.57%, lo que indica que sus variaciones diarias habituales fueron significativamente superiores al resto de compañías analizadas. Asimismo, concentra los valores atípicos más extremos, alcanzando aproximadamente pérdidas cercanas al -35% y ganancias superiores al 70% en un solo día, reflejando episodios de elevada incertidumbre y fuertes reacciones del mercado.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# PDD registra la segunda mayor dispersión, con un rango intercuartílico aproximado entre -2.11% y 2.29%, acompañado de valores atípicos que alcanzan alrededor del -25% y 60%. Este comportamiento confirma que ambas compañías estuvieron expuestas a fluctuaciones diarias considerablemente superiores al promedio, por lo que, aunque ofrecieron elevados rendimientos acumulados, también implicaron un mayor nivel de riesgo para los inversionistas.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# En contraste, NVIDIA, a pesar de haber obtenido el mayor rendimiento acumulado del período, presenta una distribución diaria relativamente más compacta, con un rango intercuartílico aproximado entre -1.54% y 1.99%. Esto sugiere que su crecimiento no dependió únicamente de movimientos extremos, sino de una apreciación más consistente a lo largo del tiempo. De forma similar, FICO exhibe una de las distribuciones más estrechas del grupo, indicando una menor volatilidad diaria y un comportamiento relativamente más estable, aun cuando también registró rendimientos acumulados sobresalientes.
# </p>
#
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_4 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Cómo se relacionan el volumen negociado y el precio de cierre?</b>
# </ol>
#
# </div>

# %%
# Data Question 4

df_ques4 = df[df["Company"].isin(df_ques1["Company"])][["Company", "Close", "Volume"]].copy()
source = ColumnDataSource(df_ques4)
source_all = ColumnDataSource(df_ques4)
df_ques4.columns.name = None
TABLES["table_ques4"] = df_ques4
df_ques4

# %%
# Charts Question 4

p_ques4 = figure(
    height=550, 
    width=950,
    tools="pan,wheel_zoom,reset,save,tap",
    x_axis_label="Close",
    y_axis_label="Volume",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    title="Relación Volume-Close"
)

palette = [
    "#3b82f6",  # Azul
    "#ef4444",  # Rojo
    "#22c55e",  # Verde
    "#f59e0b",  # Amarillo
    "#8b5cf6",  # Morado
    "#06b6d4",  # Cian
    "#ec4899",  # Rosa
    "#fb923c",  # Naranja
    "#84cc16",  # Lima
    "#e5e7eb"   # Gris claro
]

renderer = p_ques4.scatter(
    x="Close", 
    y="Volume",
    source=source,
    size=8,
    fill_color=factor_cmap("Company", palette=palette, factors=df_ques4["Company"].unique()),
    line_color=None
)


hover = HoverTool(tooltips="""
    <div style="background:#0b0b0b; border:1px solid #d4af37; border-radius:6px; padding:6px; color:#fff;">
        <div><b>Volume:</b> @Volume{0,0}</div>
        <div><b>Close:</b> $@Close{0.00}</div>
        <div><b>Company:</b> @Company</div>
    </div>
""", renderers=[renderer])
p_ques4.add_tools(hover)

callback = CustomJS(args=dict(source=source), code="""
    const indices = source.selected.indices;
    if (indices.length > 0) {
        const seg = source.data['Company'][indices[0]];
        const new_indices = [];
        for (let i = 0; i < source.data['Company'].length; i++) {
            if (source.data['Company'][i] === seg) {
                new_indices.push(i);
            }
        }
        source.selected.indices = new_indices;
    }
""")

taptool = p_ques4.select(type=TapTool)
taptool.callback = callback

p_ques4.yaxis.formatter = NumeralTickFormatter(format="0.00a")
p_ques4.xaxis.formatter = NumeralTickFormatter(format="0.00a")
p_ques4.title.text_color = theme["ACCENT"] 
p_ques4.title.text_font_size = "20pt"        
p_ques4.title.align = "center"  
p_ques4.xaxis.axis_label_text_color = theme["TEXT"]
p_ques4.yaxis.axis_label_text_color = theme["TEXT"]
p_ques4.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques4.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques4.outline_line_color = theme["BORDER"]
p_ques4.xgrid.grid_line_color = theme["GRID"]
p_ques4.ygrid.grid_line_color = theme["GRID"]
p_ques4.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques4.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques4.toolbar.logo = None
p_ques4.toolbar.autohide = True

select = Select(
    title="Empresa",
    value="Todas",
    options=["Todas"] + sorted(df_ques4["Company"].unique().tolist())
)

select.stylesheets = [
    InlineStyleSheet(css=f"""
    .bk-input {{
        background: {theme["PANEL"]} !important;
        color: {theme["TEXT"]} !important;
        border: 1px solid {theme["BORDER"]} !important;
        border-radius: 6px;
        font-weight: 500;
    }}

    .bk-input:hover {{
        border-color: {theme["ACCENT"]} !important;
    }}

    .bk-input:focus {{
        border-color: {theme["ACCENT"]} !important;
        box-shadow: 0 0 5px {theme["ACCENT"]};
    }}

    .bk-input option {{
        background: {theme["PANEL"]};
        color: {theme["TEXT"]};
    }}

    .bk-input-group label {{
        color: {theme["TEXT"]} !important;
        font-weight: bold;
    }}
    """)
]
callback = CustomJS(args=dict(source=source, source_all=source_all, select=select), code="""
const empresa = select.value;

const data = source.data;
const original = source_all.data;

for (const key in data){
    data[key] = [];
}

for (let i = 0; i < original["Company"].length; i++){

    if (empresa === "Todas" || original["Company"][i] === empresa){

        for (const key in data){
            data[key].push(original[key][i]);
        }

    }
}

source.change.emit();
""")

select.js_on_change("value", callback)

CHARTS["chart_ques4"] = column(p_ques4)
show(column(p_ques4, select))

# %% [markdown]
# <!-- EXPORT: ANALISIS_4 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# La relación entre el volumen negociado y el precio de cierre evidencia comportamientos distintos entre las empresas con mayor rendimiento acumulado. TSLA presenta la mayor dispersión en el volumen de negociación, alcanzando registros superiores a los 900 millones de acciones negociadas en algunas jornadas, mientras que sus precios de cierre oscilaron hasta aproximadamente los $400. Sin embargo, la distribución de los puntos no refleja un patrón lineal claro, lo que indica que un mayor volumen negociado no implica necesariamente un mayor precio de cierre.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# NVDA muestra un comportamiento más concentrado en términos de volumen, con valores que rara vez superan los 250 millones de acciones negociadas, aunque alcanza precios de cierre cercanos a los \$500. En contraste, BNTX registra volúmenes considerablemente menores, generalmente inferiores a los 20 millones de acciones, pero mantiene precios de cierre comparables a los de empresas con una actividad bursátil mucho mayor, alcanzando valores cercanos a los $400. Esto evidencia que el nivel del precio de una acción no depende directamente de la cantidad de títulos negociados durante una sesión.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# En términos generales, la mayor parte de las empresas concentra sus observaciones por debajo de los 200 millones de acciones negociadas. Asimismo, FICO destaca por registrar los precios de cierre más elevados del conjunto, superando los $1,100 por acción, pese a mantener volúmenes de negociación relativamente bajos en comparación con otras compañías. En conjunto, la dispersión observada sugiere una relación débil entre el volumen negociado y el precio de cierre, indicando que ambas variables responden a factores distintos y que el incremento en el volumen de negociación no se traduce necesariamente en un incremento proporcional en el precio de la acción.
# </p>
# </p>
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_5 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Qué empresas registran los mayores volúmenes de negociación?</b>
# </ol>
#
# </div>

# %%
# Data Question 5
df_ques5 = ( df.groupby("Company", as_index=False).agg(Volumen_Total=("Volume", "sum")).sort_values("Volumen_Total", ascending=False).head(10).reset_index(drop=True))
df_ques5["Volumen_txt"] = (df_ques5["Volumen_Total"] / 1_000_000_000).round(2).astype(str) + " B"
source = ColumnDataSource(df_ques5)
df_ques5.columns.name = None
TABLES["table_ques5"] = df_ques5
df_ques5

# %%
# Chart Question 5

p_ques5 = figure(
    y_range=list(df_ques5["Company"])[::-1],  
     x_range=(0, 185000000000),
    x_axis_type="linear",
    height=550, 
    width=950,
    tools="xpan,xwheel_zoom,reset,save",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    title="Volumen total por compañia"
)

p_ques5.segment(
    x0=0, 
    y0="Company",
    x1="Volumen_Total", 
    y1="Company",
    source=source,
    line_color=theme["ACCENT"], 
    line_width=5
)


p_ques5.scatter(
    x="Volumen_Total", 
    y="Company",
    source=source,
    size=15,
    color=theme["ACCENT"],
    line_color=theme["BORDER"]
)

p_ques5.scatter(
    x="Volumen_Total", y="Company",
    source=source,
    size=10,
    color=theme["TEXT"],
    line_color=theme["TEXT"]
)

labels = LabelSet(
    x="Volumen_Total",       
    y="Company",         
    text="Volumen_txt", 
    level="glyph",
    x_offset=10,           
    y_offset=0,             
    source=source,
    text_font_size="10pt",
    text_color=theme["TEXT"]
)

hover = HoverTool(
    tooltips=f"""
    <div style="
        background:{theme['BACKGROUND']};
        border:1px solid {theme['ACCENT']};
        border-radius:8px;
        padding:6px 10px;
        color:{theme['TEXT']};
    ">
        <div><span style="color:{theme['ACCENT']};">Compañia:</span> @Company</div>
        <div><span style="color:{theme['ACCENT']};">Volumen:</span> @Volumen_Total{{0.00a}}</div>
    </div>
    """,
    mode="mouse",
    renderers=[p_ques5.renderers[-1]]  
)
p_ques5.add_tools(hover)
p_ques5.add_layout(labels)
p_ques5.xaxis.formatter = NumeralTickFormatter(format="0.00a")
p_ques5.title.text_color = theme["ACCENT"] 
p_ques5.title.text_font_size = "20pt"        
p_ques5.title.align = "center"  
p_ques5.xaxis.axis_label_text_color = theme["TEXT"]
p_ques5.yaxis.axis_label_text_color = theme["TEXT"]
p_ques5.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques5.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques5.outline_line_color = theme["BORDER"]
p_ques5.xgrid.grid_line_color = theme["GRID"]
p_ques5.ygrid.grid_line_color = theme["GRID"]
p_ques5.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques5.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques5.toolbar.logo = None
p_ques5.toolbar.autohide = True

CHARTS["chart_ques5"] = p_ques5
show(p_ques5)

# %% [markdown]
# <!-- EXPORT: ANALISIS_5 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# El volumen acumulado de negociación muestra que <b>TSLA</b> fue la empresa con la mayor actividad bursátil durante el período de análisis, acumulando aproximadamente <b>168.48 mil millones de acciones negociadas</b>. En segundo lugar se ubicó <b>AAPL</b> con <b>130.58 mil millones</b>, seguida por <b>AMD</b> con <b>97.65 mil millones</b>. Estos resultados reflejan que dichas empresas concentraron una parte importante de la actividad de negociación del mercado, evidenciando un elevado interés por parte de los inversionistas y una alta liquidez de sus acciones.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Asimismo, se observa una diferencia considerable entre el primer y el décimo lugar del ranking. Mientras TSLA acumuló cerca de <b>168.48 mil millones</b> de acciones negociadas, la décima empresa registró aproximadamente <b>42.61 mil millones</b>, lo que representa apenas una cuarta parte del volumen alcanzado por TSLA. Esto evidencia que la actividad de negociación estuvo concentrada en un reducido grupo de compañías de gran capitalización y elevada liquidez.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Es importante señalar que un mayor volumen de negociación no implica necesariamente un mayor rendimiento de la acción. El volumen representa la cantidad de acciones que cambiaron de manos durante el período, por lo que constituye un indicador de liquidez e interés del mercado, pero no garantiza incrementos sostenidos en el precio de la acción.
# </p>
#
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_6 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Cuál fue el rendimiento mensual promedio de cada empresa?</b>
# </ol>
#
# </div>

# %%
# Data Question 6

df_ques6 = (df[df["Company"].isin(df_ques1["Company"])][["fecha", "Company", "Close"]].copy())
df_ques6["Año"] = df_ques6["fecha"].dt.year
df_ques6["Mes"] = df_ques6["fecha"].dt.month_name().str[:3]
df_ques6 = (df_ques6.sort_values("fecha").groupby(["Company","Año","Mes"], as_index=False).last())
df_ques6["Rendimiento"] = (df_ques6.groupby("Company")["Close"].pct_change() * 100)
df_ques6 = (df_ques6.groupby(["Company","Mes"], as_index=False).agg(Rendimiento=("Rendimiento","mean")))
orden = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
df_ques6["Mes"] = pd.Categorical(df_ques6["Mes"], categories=orden, ordered=True)
df_ques6 = df_ques6.sort_values(["Company","Mes"])
source = ColumnDataSource(df_ques6)
df_ques6.columns.name = None
TABLES["table_ques6"] = df_ques6
df_ques6

# %%
# Chart Question 6

lim = max(
    abs(df_ques6["Rendimiento"].min()),
    abs(df_ques6["Rendimiento"].max())
)

mapper = linear_cmap(
    field_name="Rendimiento",
    palette=Inferno256,
    low=-lim,
    high=lim
)

p_ques6 = figure(
    width=950,
    height=550,
    x_range=orden,
    y_range=list(reversed(sorted(df_ques6["Company"].unique()))),
    title="Rendimiento mensual promedio",
    tools="pan,reset,save",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"]
)

renderer = p_ques6.rect(
    x="Mes",
    y="Company",
    width=1,
    height=1,
    source=source,
    fill_color=mapper,
    line_color=theme["BACKGROUND"]
)

hover = HoverTool(
    renderers=[renderer],
    tooltips="""
    <div style="
        background:#111827;
        border:1px solid #3b82f6;
        border-radius:8px;
        padding:10px;
        color:#f8fafc;
    ">
        <div><b>Empresa:</b> @Company</div>
        <div><b>Mes:</b> @Mes</div>
        <div><b>Rendimiento:</b> @Rendimiento{0.00}%</div>
    </div>
    """
)

color_bar = ColorBar(
    color_mapper=mapper["transform"],
    width=12,
    background_fill_color=theme["PANEL"],
    major_label_text_color=theme["TEXT"],
    major_label_text_font_size="11pt",
    major_tick_line_color=theme["TEXT_SOFT"],
    minor_tick_line_color=None,
    bar_line_color=theme["BORDER"],
    border_line_color=theme["BORDER"],
    title_text_color=theme["ACCENT"],
    title_text_font_size="12pt"
)

p_ques6.add_layout(color_bar, "right")
p_ques6.add_tools(hover)
p_ques6.xaxis.major_label_orientation = 1.0  
p_ques6.title.text_color = theme["ACCENT"] 
p_ques6.title.text_font_size = "20pt"        
p_ques6.title.align = "center"  
p_ques6.xaxis.axis_label_text_color = theme["TEXT"]
p_ques6.yaxis.axis_label_text_color = theme["TEXT"]
p_ques6.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques6.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques6.outline_line_color = theme["BORDER"]
p_ques6.xgrid.grid_line_color = theme["GRID"]
p_ques6.ygrid.grid_line_color = theme["GRID"]
p_ques6.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques6.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques6.toolbar.logo = None
p_ques6.toolbar.autohide = True
p_ques6.add_layout(color_bar, "right")

CHARTS["chart_ques6"] = p_ques6
show(p_ques6)

# %% [markdown]
# <!-- EXPORT: ANALISIS_6 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# El rendimiento mensual promedio de las empresas con mayor rendimiento acumulado durante el período 2019–2023 evidencia la existencia de un comportamiento estacional relativamente similar entre la mayoría de compañías. Los primeros meses del año (enero, febrero y marzo) registran predominantemente rendimientos promedio negativos, aunque destacan excepciones como <b>PDD</b>, que alcanzó un rendimiento promedio de <b>13.88%</b> en este período. En contraste, <b>BNTX</b> presentó el promedio más bajo, con una caída de <b>-28.27%</b>, reflejando una elevada sensibilidad a las condiciones del mercado.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Durante abril y mayo se observa una recuperación generalizada de los rendimientos promedio, donde prácticamente todas las empresas registran valores positivos. Posteriormente, junio representa un punto de desaceleración, con una disminución del rendimiento promedio en la mayoría de compañías. En julio y agosto vuelve a apreciarse un comportamiento favorable, siendo estos algunos de los meses con mejores resultados del período, especialmente para <b>BNTX</b>, que alcanzó un rendimiento promedio cercano al <b>82.76%</b>.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Finalmente, septiembre y octubre muestran nuevamente una tendencia negativa en la mayoría de empresas, mientras que noviembre y diciembre presentan una recuperación con rendimientos promedio positivos. En términos generales, <b>BNTX</b> es la empresa que exhibe la mayor variabilidad entre meses, alternando fuertes caídas y elevados crecimientos, lo que confirma el comportamiento altamente volátil observado en análisis anteriores. Por el contrario, empresas como <b>FICO</b> presentan cambios mensuales más moderados, reflejando una mayor estabilidad en sus rendimientos a lo largo del período analizado.
# </p>
#
#
# </div>

# %% [markdown]
# <!-- EXPORT: PREGUNTA_7 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ol style="
# font-size:25px;
# color:#d1d5db;
# line-height:1.5;
# padding-left:25px;
# ">
# <b>¿Qué tan consistentes fueron los rendimientos diarios de las empresas con mayor rendimiento acumulado?</b>
# </ol>
#
# </div>

# %%
# Data Question 7

df_ques7 = (df[df["Company"].isin(df_ques1["Company"])][["fecha", "Company", "Close"]].copy())
df_ques7 = df_ques7.sort_values(["Company", "fecha"])
df_ques7["Retorno_Diario"] = (df_ques7.groupby("Company")["Close"].pct_change() * 100)
df_ques7 = df_ques7.dropna()
source = ColumnDataSource(df_ques7)
df_ques7.columns.name = None
TABLES["table_ques7"] = df_ques7
df_ques7

# %%
# Chart Question 7

empresas = df_ques7["Company"].unique()
xmin = df_ques7["Retorno_Diario"].quantile(0.01)
xmax = df_ques7["Retorno_Diario"].quantile(0.99)
x = np.linspace(-10, 10, 400)

p_ques7 = figure(
    width=950,
    height=550,
    title="Distribución de los rendimientos diarios",
    background_fill_color=theme["BACKGROUND"],
    border_fill_color=theme["PANEL"],
    tools="pan,wheel_zoom,reset,save"
)

offset = 0

for empresa in empresas:
    datos = df_ques7.loc[ df_ques7["Company"] == empresa, "Retorno_Diario"]
    kde = gaussian_kde(datos)
    y = kde(x)
    y = y / y.max() * 0.75
    
    p_ques7.patch(
        np.concatenate([x, x[::-1]]),
        np.concatenate([
            y + offset,
            np.repeat(offset, len(x))
        ]),
        alpha=0.75,
        line_color="white"
    )

    p_ques7.line(
        x,
        y + offset,
        line_width=2
    )

    offset += 1

p_ques7.yaxis.ticker = list(range(len(empresas)))
p_ques7.yaxis.major_label_overrides = {i: empresa for i, empresa in enumerate(empresas)}
p_ques7.xaxis.formatter = NumeralTickFormatter(format="0.00a")
p_ques7.title.text_color = theme["ACCENT"] 
p_ques7.title.text_font_size = "20pt"        
p_ques7.title.align = "center"  
p_ques7.xaxis.axis_label_text_color = theme["TEXT"]
p_ques7.yaxis.axis_label_text_color = theme["TEXT"]
p_ques7.xaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques7.yaxis.major_label_text_color = theme["TEXT_SOFT"]
p_ques7.outline_line_color = theme["BORDER"]
p_ques7.xgrid.grid_line_color = theme["GRID"]
p_ques7.ygrid.grid_line_color = theme["GRID"]
p_ques7.xgrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques7.ygrid.grid_line_alpha = theme["GRID_ALPHA"]
p_ques7.toolbar.logo = None
p_ques7.toolbar.autohide = True

CHARTS["chart_ques7"] = p_ques7
show(p_ques7)

# %% [markdown]
# <!-- EXPORT: ANALISIS_7 -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# La distribución de los rendimientos diarios confirma diferencias importantes en la volatilidad entre las empresas analizadas. <b>TSLA</b>, <b>PDD</b> y <b>BNTX</b> presentan las distribuciones más amplias, lo que indica una mayor dispersión de los rendimientos diarios y, por tanto, un comportamiento más volátil. Este resultado es consistente con los análisis previos, donde estas compañías también mostraron mayores fluctuaciones en los rendimientos acumulados y mensuales.
# </p>
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Por el contrario, <b>SNPS</b>, <b>KLAC</b>, <b>FICO</b>, <b>CDNS</b> y <b>ARES</b> exhiben distribuciones considerablemente más concentradas alrededor del rendimiento promedio, reflejando una menor dispersión y una mayor estabilidad en las variaciones diarias de sus precios. Por su parte, <b>AMD</b> y <b>NVDA</b> ocupan una posición intermedia, mostrando una dispersión superior a la de las empresas más estables, pero inferior a la observada en <b>TSLA</b>, <b>PDD</b> y <b>BNTX</b>.
# </p>
#
# <p style="
# font-size:15px;
# color:#d1d5db;
# line-height:1.5;
# text-align:justify;
# ">
# Finalmente, se observa que todas las distribuciones se encuentran centradas alrededor del <b>0&nbsp;%</b>, lo que indica que las diferencias entre empresas no radican en el rendimiento diario promedio, sino en la magnitud de las variaciones que experimentan día a día. En consecuencia, las empresas con distribuciones más amplias implican un mayor nivel de riesgo, ya que presentan cambios más pronunciados en el precio de sus acciones.
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h1 style="
# font-size:35px;
# color:#60a5fa;
# text-align:center;
# margin-top:0;
# margin-bottom:10px;
# ">
# Conclusiones y Recomendaciones
# </h1>
#
# <hr style="border:5px solid #60a5fa; margin-bottom:30px;">
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:0px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
#
# <h3 style="
# font-size:35px;
# color:#60a5fa;
# margin-bottom:10px;
# ">
# Conclusiones
# </h3>

# %% [markdown]
# <!-- EXPORT: CONCLUSIONES -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ul style="
# font-size:17px;
# color:#d1d5db;
# line-height:1.8;
# text-align:justify;
# ">
#
# <li>
# Durante el período 2018–2025 las empresas analizadas mostraron diferencias significativas tanto en su rendimiento acumulado como en su nivel de riesgo. NVIDIA obtuvo el mayor rendimiento acumulado del conjunto, mientras que Tesla y BioNTech también registraron crecimientos sobresalientes, aunque acompañados de una mayor volatilidad.
# </li>
#
# <li>
# La evolución de los precios de cierre evidenció que un alto rendimiento no necesariamente implica un comportamiento altamente inestable. Mientras BNTX experimentó fuertes incrementos seguidos de importantes correcciones, NVIDIA mantuvo una trayectoria de crecimiento más sostenida y consistente durante el período analizado.
# </li>
#
# <li>
# Los análisis de volatilidad, rendimientos diarios y distribuciones de densidad mostraron que BNTX, TSLA y PDD fueron las empresas con mayor dispersión en sus retornos, mientras que compañías como SNPS, KLAC, CDNS, FICO y ARES registraron comportamientos considerablemente más estables.
# </li>
#
# <li>
# El volumen de negociación permitió identificar a Tesla, Apple y AMD como las empresas con mayor liquidez del mercado. Sin embargo, no se encontró una relación lineal clara entre el volumen negociado y el precio de cierre, lo que indica que ambas variables responden a factores distintos del comportamiento bursátil.
# </li>
#
# <li>
# El análisis mensual evidenció ciertos patrones estacionales compartidos entre las empresas, observándose meses con rendimientos promedio predominantemente positivos y otros con resultados negativos. No obstante, la magnitud de dichos cambios varía considerablemente entre compañías, reforzando la importancia de analizar tanto el rendimiento esperado como el nivel de riesgo asociado.
# </li>
#
# </ul>
#
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h3 style="
# font-size:35px;
# color:#60a5fa;
# margin-top:10px;
# margin-bottom:10px;
# ">
# Recomendaciones
# </h3>

# %% [markdown]
# <!-- EXPORT: RECOMENDACIONES -->
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <ul style="
# font-size:17px;
# color:#d1d5db;
# line-height:1.8;
# text-align:justify;
# ">
#
# <li>
# Complementar el análisis exploratorio con indicadores financieros adicionales, con el fin de evaluar el rendimiento ajustado por riesgo de cada empresa.
# </li>
#
# <li>
# Incorporar variables fundamentales, tales como ingresos, utilidades, capitalización bursátil, indicadores macroeconómicos o tasas de interés, para comprender mejor los factores que explican el comportamiento de las acciones.
# </li>
#
# <li>
# Profundizar en el análisis de la relación entre precio y volumen mediante medidas estadísticas como correlaciones o modelos de regresión, permitiendo cuantificar el grado de asociación entre ambas variables.
# </li>
#
# <li>
# Realizar análisis por subperíodos o eventos relevantes (por ejemplo, pandemia de COVID-19, cambios en política monetaria o publicación de resultados financieros) para identificar cómo diferentes escenarios afectaron el comportamiento bursátil de las empresas.
# </li>
#
# <li>
# Utilizar los resultados obtenidos como punto de partida para construir modelos predictivos o estrategias de inversión que combinen rendimiento esperado, volatilidad y liquidez, permitiendo una toma de decisiones más informada y fundamentada.
# </li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# background:#1e1e1e;
# padding:30px;
# border:3px solid #3b82f6;
# border-radius:15px;
# margin:20px 0;
# box-shadow:0 0 20px rgba(59,130,246,.15);
# ">
#
# <h1 style="
# font-size:55px;
# color:#60a5fa;
# text-align:center;
# margin-top:0;
# margin-bottom:10px;
# ">
# Exportar Proyecto
# </h1>
#
# <hr style="border:5px solid #60a5fa; margin-bottom:30px;">
#
# </div>

# %%
#Export Tables

export_tables.exportar_tablas(TABLES)

# %%
#Export Charts

export_charts.exportar_graficas(CHARTS)

# %%
#Export Text

export_text.exportar_reporte_textos("caso 4.ipynb")

# %%
import numpy as np
import pandas as pd
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, Range1d
from bokeh.io import export_png

# ========================================
# GENERAR DATOS ALEATORIOS (Mock Data)
# ========================================
def get_random_temporal_data():
    years = range(2021, 2026)
    quarters = [1, 2, 3, 4]
    x_categories = [f"{y}-Q{q}" for y in years for q in quarters]
    
    regions = ["Región Norte", "Región Sur", "Región Este", "Región Oeste", "Región Central"]
    
    data = {"period": x_categories, "anio": x_categories, "regions": regions}
    
    np.random.seed(42) 
    total_abs_list = []
    
    for x in x_categories:
        tot = np.random.randint(10000, 50000)
        total_abs_list.append(tot)

    data["total"] = total_abs_list

    for r in regions:
        region_vals = []
        region_pcts = []
        for tot in total_abs_list:
            pct = np.random.uniform(0.1, 0.4)
            log_val = np.log(tot + 1) * pct
            region_vals.append(round(log_val, 6))
            region_pcts.append(round(pct * 100, 2))
            
        data[r] = region_vals
        data[f"{r}_pct"] = region_pcts

    return data

# ========================================
# CREAR Y EXPORTAR CHART (PNG LIMPIO)
# ========================================
def generate_temporal_png(temporal_data, output_filename="portada_grafica.png"):
    years = temporal_data.get("anio", [])
    regions = temporal_data.get("regions", [])
    totals = temporal_data.get("total", [])

    x_vals = years if len(years) > 0 else ["-"]

    bars_source = ColumnDataSource(data={"anio": x_vals, **{r: temporal_data.get(r, [0] * len(x_vals)) for r in regions}})
    
# Normalizamos la línea y la elevamos un poco más para que luzca bien sobre las barras
    max_tot = max(totals) if totals and max(totals) > 0 else 1
    normalized_totals = [t / max_tot * 20 for t in totals] if totals else [0] * len(x_vals)
    
    line_source = ColumnDataSource(data={"anio": x_vals, "total_norm": normalized_totals})

    gold_palette = [
        "#1a1a1a", "#222222", "#2c2418",
        "#3a3120", "#4a3b1d", "#5c4a1f", "#6d5422"
    ]
    colors = [gold_palette[i % len(gold_palette)] for i in range(len(regions))]

    p = figure(
        x_range=x_vals,
        height=600,       
        width=1000,       
        toolbar_location=None, 
        background_fill_color=theme["BACKGROUND"],
        border_fill_color=theme["BACKGROUND"],
        min_border=0,             # <-- ELIMINA EL MARGEN INTERNO POR DEFECTO DE BOKEH
        min_border_left=0,
        min_border_right=0,
        min_border_top=0,
        min_border_bottom=0
    )

    p.y_range = Range1d(0, 1)

    # ========================================
    # OCULTAR COMPLETAMENTE TODO LO INNECESARIO
    # ========================================

    p.xaxis.visible = False
    p.yaxis.visible = False
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    p.outline_line_color = None      # <-- Elimina el borde exterior del gráfico
    p.border_fill_color = None       # <-- Quita el color del panel de bordes para que sea transparente
    p.background_fill_color = theme["BACKGROUND"]

    # Barras apiladas
    p.vbar_stack(
        regions, x="anio", width=0.5, color=colors,
        line_color=theme["POSITIVE"], border_radius=100, line_width=0.7,
        source=bars_source
    )

    # Línea de tendencia (usando el eje principal normalizado)
    p.line(
        x='anio', y='total_norm', source=line_source, line_width=5,
        color=theme["ACCENT"], alpha=1
    )
    p.scatter(
        x='anio', y='total_norm', source=line_source, size=15,
        fill_color=theme["TEXT"], line_color=theme["ACCENT"],
        line_width=5
    )

    # Ajuste inicial del rango izquierdo
    try:
        ds = bars_source.data
        if len(x_vals) > 0 and len(regions) > 0:
            sum_logs = np.zeros(len(x_vals))
            for r in regions:
                col = np.array(ds.get(r, [0] * len(x_vals)), dtype=float)
                sum_logs += col
            max_sum = float(np.nanmax(sum_logs)) if sum_logs.size > 0 else 1.0
            p.y_range.start = 0
            p.y_range.end = max_sum * 1.15
    except Exception:
        p.y_range.start = 0
        p.y_range.end = 1
        
    # Exportar el gráfico a PNG (con timeout ampliado para evitar fallos de Selenium)
    export_png(p, filename=output_filename, timeout=15)
    print(f"Gráfica guardada exitosamente en {output_filename}")

# ========================================
# EJECUCIÓN DIRECTA
# ========================================
if __name__ == "__main__":
    fake_data = get_random_temporal_data()
    generate_temporal_png(fake_data, "../charts/portada_grafica.png")

# %%
#Generar Reporte

report.generar_reporte()
